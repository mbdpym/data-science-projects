# %% [markdown]
# # Salvando dataframes em CSV, Excel e JSON

# %%
import pandas as pd
import numpy as np

# %%
rounded_matrix = np.round(np.random.random_sample(size=(100, 10)) * 100, 2)
rounded_matrix
# Out:
# array([[5.565e+01, 5.588e+01, 6.581e+01, 2.302e+01, 8.735e+01, 3.561e+01,
#         3.272e+01, 6.621e+01, 2.809e+01, 4.135e+01],
#        [2.940e+00, 4.843e+01, 3.402e+01, 9.709e+01, 4.020e+01, 8.565e+01,
#         2.468e+01, 1.000e+01, 9.668e+01, 2.660e+00],
#        [3.803e+01, 2.665e+01, 4.899e+01, 7.072e+01, 3.436e+01, 1.646e+01,
#         2.678e+01, 6.510e+00, 9.708e+01, 6.688e+01],
#        [1.164e+01, 7.487e+01, 2.998e+01, 5.800e-01, 5.908e+01, 2.140e+00,
#         9.609e+01, 5.221e+01, 6.647e+01, 6.187e+01],
#        [9.232e+01, 4.960e+01, 8.640e+01, 5.413e+01, 4.803e+01, 1.585e+01,
#         1.960e+01, 7.490e+01, 9.181e+01, 5.087e+01],
#        [1.620e+00, 8.323e+01, 6.890e+00, 5.374e+01, 9.034e+01, 9.132e+01,
#         9.495e+01, 5.940e+00, 1.828e+01, 3.508e+01],
#        [3.910e+00, 6.709e+01, 4.350e+00, 6.146e+01, 9.755e+01, 3.665e+01,
#         3.472e+01, 3.361e+01, 3.160e+00, 2.458e+01],
#        [5.626e+01, 9.122e+01, 8.377e+01, 9.287e+01, 9.665e+01, 1.240e+01,
# ...

# %%
df = pd.DataFrame(rounded_matrix, 
            columns = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])

# %%
df.head(10)
# Out:
#        A      B      C      D      E      F      G      H      I      J
# 0  55.65  55.88  65.81  23.02  87.35  35.61  32.72  66.21  28.09  41.35
# 1   2.94  48.43  34.02  97.09  40.20  85.65  24.68  10.00  96.68   2.66
# 2  38.03  26.65  48.99  70.72  34.36  16.46  26.78   6.51  97.08  66.88
# 3  11.64  74.87  29.98   0.58  59.08   2.14  96.09  52.21  66.47  61.87
# 4  92.32  49.60  86.40  54.13  48.03  15.85  19.60  74.90  91.81  50.87
# 5   1.62  83.23   6.89  53.74  90.34  91.32  94.95   5.94  18.28  35.08
# 6   3.91  67.09   4.35  61.46  97.55  36.65  34.72  33.61   3.16  24.58
# 7  56.26  91.22  83.77  92.87  96.65  12.40  33.01  61.51  35.87   6.34
# 8  30.65  45.41  19.03  74.35  52.46  82.40  49.85  72.90  46.86  80.01
# 9  99.47  65.77  83.75   9.47  65.44  33.83  62.78  98.54  92.41   5.53

# %% [markdown]
# ## Salvando em CSV

# %%
df.to_csv('dataframe_aleatorio.csv')

# %%
df.to_csv('./output/dataframe_aleatorio.csv')

# %%
df.to_csv('./output/dataframe_aleatorio_index.csv', index= False)

# %%
df.to_csv('./output/dataframe_aleatorio_index_sep.csv', index= False, sep=';')

# %%
df.to_csv('./output/dataframe_aleatorio_index_sep_dec.csv', index= False, sep=';', decimal=',')

# %% [markdown]
# ## Salvando em Excel

# %%
df.to_excel('./output/dataframe_aleatorio.xlsx')

# %%
df.to_excel('./output/dataframe_aleatorio_index.xlsx',
            index=False,
            startrow=1,
            sheet_name='aleatorio')

# %% [markdown]
# ## Salvando em JSON

# %%
df.to_json('./output/dataframe_aleatorio.json')
